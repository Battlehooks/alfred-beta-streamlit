# %%
huggingface_key = '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'
openai_key = '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'

# %%
import numpy as np
import pandas as pd
from pprint import pprint

# %%
url_data = pd.read_csv('youtube_url_ikea.tsv', delimiter = '\t')
url_data
# Out:
#           name                                              title  \
# 0         ADDE  Assembling IKEA furniture - ADDE - Chair (stac...
# 1         ADDE  ADDE chair black from IKEA : open box and asse...
# 2         ADDE  HOW TO Assemble IKEA ADDE Chair | Unboxing & A...
# 3        POÄNG                   How to Assemble IKEA Poang Chair
# 4        POÄNG                       Ikea Poang Armchair Tutorial
# ..         ...                                                ...
# 151  GAMMALBYN  How To Easily Install IKEA Furniture At Home |...
# 152  GAMMALBYN  Ikea sofa installation | Ormaryd sofa | IKEA s...
# 153   HÄRLANDA  IKEA Harlanda Sofa 🛋- how to 🛠 🧰 furniture vid...
# 154   HÄRLANDA                   IKEA - HÄRLANDA build and review
# 155   HÄRLANDA  Ikea GRÖNLID 4 seat sofa with chaise longue As...
#
#                                                   href
# 0    https://www.youtube.com/watch?v=_wzZav6bBO8&pp...
# 1    https://www.youtube.com/watch?v=NgtHzIX02tQ&pp...
# ...

# %%
ikea_data = pd.read_csv('ikea_ds.tsv', delimiter = '\t')
ikea_data
# Out:
#           name      type  ratingValue  ratingCount       price  \
# 0         ADDE     Chair          4.5          651    15.0 USD
# 1         ADDE     Chair          4.5          651    15.0 USD
# 2         ADDE     Chair          4.5          651    15.0 USD
# 3        POÄNG  Armchair          4.7          318   119.0 USD
# 4        POÄNG  Armchair          4.7          318   119.0 USD
# ..         ...       ...          ...          ...         ...
# 151  GAMMALBYN      Sofa          4.2           50   499.0 USD
# 152  GAMMALBYN      Sofa          4.2           50   499.0 USD
# 153   HÄRLANDA      Sofa          3.8           33  1099.0 USD
# 154   HÄRLANDA      Sofa          3.8           33  1099.0 USD
# 155   HÄRLANDA      Sofa          3.8           33  1099.0 USD
#
#                                                    url  \
# 0    https://www.ikea.com/us/en/p/adde-chair-white-...
# 1    https://www.ikea.com/us/en/p/adde-chair-white-...
# ...

# %%
ikea_data = ikea_data.drop_duplicates(subset = ['name']).reset_index(drop = True)
ikea_data
# Out:
#                      name                                type  ratingValue  \
# 0                    ADDE                               Chair          4.5
# 1                   POÄNG                            Armchair          4.7
# 2                  ÖSTANÖ                               Chair          4.5
# 3                 JÄTTEBO  Cover 1.5-seat module with storage          0.0
# 4               STRANDMON                          Wing chair          4.6
# 5      LOBERGET / MALSKÄR                  Swivel chair + pad          4.6
# 6                EKENÄSET                            Armchair          4.7
# 7                   LIDÅS                               Chair          4.7
# 8                   KIVIK                 1-seat sleeper sofa          3.8
# 9                TEODORES                               Chair          4.7
# 10                 TOBIAS                               Chair          4.1
# ...

# %%
ikea_data['text'] = ikea_data['name'] + ' [SEP] ' + ikea_data['type'] + ' [SEP] ' + ikea_data['description']
ikea_data
# Out:
#                      name                                type  ratingValue  \
# 0                    ADDE                               Chair          4.5
# 1                   POÄNG                            Armchair          4.7
# 2                  ÖSTANÖ                               Chair          4.5
# 3                 JÄTTEBO  Cover 1.5-seat module with storage          0.0
# 4               STRANDMON                          Wing chair          4.6
# 5      LOBERGET / MALSKÄR                  Swivel chair + pad          4.6
# 6                EKENÄSET                            Armchair          4.7
# 7                   LIDÅS                               Chair          4.7
# 8                   KIVIK                 1-seat sleeper sofa          3.8
# 9                TEODORES                               Chair          4.7
# 10                 TOBIAS                               Chair          4.1
# ...

# %%
from langchain.document_loaders import DataFrameLoader
from langchain import HuggingFaceHub, PromptTemplate, FAISS, HuggingFacePipeline
from langchain.vectorstores import Chroma
from langchain.retrievers.multi_query import MultiQueryRetriever
from langchain.embeddings import HuggingFaceEmbeddings, OpenAIEmbeddings, SpacyEmbeddings, HuggingFaceHubEmbeddings, CacheBackedEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.storage import InMemoryStore, LocalFileStore, RedisStore
import os
import openai

os.environ['HUGGINGFACEHUB_API_TOKEN'] = huggingface_key
os.environ['OPENAI_API_KEY'] = openai_key

# %%
loader = DataFrameLoader(ikea_data, page_content_column = 'imgAlt')
docs = loader.load()

# %%
embeddings = OpenAIEmbeddings()
fs = LocalFileStore('./cache_embed/')
cache_embed = CacheBackedEmbeddings.from_bytes_store(
    embeddings, fs, namespace = embeddings.model
)

# %%
faissdb = FAISS.from_documents(docs, cache_embed)
faissdb

# %%
pprint(faissdb.similarity_search_with_score('Ajje'))
# Out:
# [(Document(page_content='JOKKMOKK Table and 4 chairs, antique stain', metadata={'name': 'JOKKMOKK', 'type': 'Table and 4 chairs', 'ratingValue': 4.6, 'ratingCount': 556, 'price': '199.99 USD', 'url': 'https://www.ikea.com/us/en/p/jokkmokk-table-and-4-chairs-antique-stain-50211104/', 'imgUrl': 'https://www.ikea.com/us/en/images/products/jokkmokk-table-and-4-chairs-antique-stain__0736929_pe740809_s5.jpg', 'description': 'Easy to bring home since the whole dining set is packed in one box.\nThe wood expression and design of the backrest bring a traditional look to the room.\nEnhance the comfort by adding soft chair pads that fit the seat perfectly.\nPine ages beautifully as the color deepens and becomes richer over time.\nDurable solid wood and antique color finish will outlast many years of use.\nWe have tested it for you! The table’s surface is resistant to liquids, food stains, oil, heat, scratches and bumps, while its construction is stable, strong and durable to withstand years of d
# ...

# %%
pprint(faissdb.similarity_search_with_score('Ajje'))
# Out:
# [(Document(page_content='JOKKMOKK Table and 4 chairs, antique stain', metadata={'name': 'JOKKMOKK', 'type': 'Table and 4 chairs', 'ratingValue': 4.6, 'ratingCount': 556, 'price': '199.99 USD', 'url': 'https://www.ikea.com/us/en/p/jokkmokk-table-and-4-chairs-antique-stain-50211104/', 'imgUrl': 'https://www.ikea.com/us/en/images/products/jokkmokk-table-and-4-chairs-antique-stain__0736929_pe740809_s5.jpg', 'description': 'Easy to bring home since the whole dining set is packed in one box.\nThe wood expression and design of the backrest bring a traditional look to the room.\nEnhance the comfort by adding soft chair pads that fit the seat perfectly.\nPine ages beautifully as the color deepens and becomes richer over time.\nDurable solid wood and antique color finish will outlast many years of use.\nWe have tested it for you! The table’s surface is resistant to liquids, food stains, oil, heat, scratches and bumps, while its construction is stable, strong and durable to withstand years of d
# ...

# %%
faissdb.save_local('faiss_index')
